# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
df=pd.read_csv('train (2).csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
plt.hist(df['SalePrice'])
plt.title('histogram of SalePrice of house')
plt.xlabel('price')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.histogram(df['SalePrice'])
# Out:
# (array([148, 723, 373, 135,  51,  19,   4,   3,   2,   2], dtype=int64),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]))

# %%
plt.boxplot(df['SalePrice'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x198b3312190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x198b3313750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x198b30910d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x198b3324790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x198b3325010>],
#  'means': []}

# %%
df['']
